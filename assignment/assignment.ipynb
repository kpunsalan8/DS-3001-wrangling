# %% [markdown]
# # Assignment: Data Wrangling
# ### `! git clone https://github.com/ds4e/wrangling`
# ### Do Q1 and Q2, and either Q3 or Q4, for a total of 3 questions.

# %% [markdown]
# **Q1.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. Categorical variable: For the Minnesota police use of for data, `./data/mn_police_use_of_force.csv`, clean the `subject_injury` variable, handling the NA's; this gives a value `Yes` when a person was injured by police, and `No` when no injury occurred. What proportion of the values are missing? Is this a concern? Cross-tabulate your cleaned `subject_injury` variable with the `force_type` variable. Are there any patterns regarding when the data are missing?
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %% [markdown]
# Q 1.1

# %%
# import necessary packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# read in airbnb csv file
df = pd.read_csv('https://raw.githubusercontent.com/kpunsalan8/DS-3001-wrangling/refs/heads/main/assignment/data/airbnb_hw.csv',low_memory=False)

# %%
# see information about df
print(df.shape, '\n') # List the dimensions of df
print(df.dtypes, '\n') # The types of the variables
print(df.columns, '\n') # Column names
# Out:
# (30478, 13)
#
# Host Id                         int64
# Host Since                     object
# Name                           object
# Neighbourhood                  object
# Property Type                  object
# Review Scores Rating (bin)    float64
# Room Type                      object
# Zipcode                       float64
# Beds                          float64
# Number of Records               int64
# Number Of Reviews               int64
# Price                          object
# Review Scores Rating          float64
# dtype: object
#
# Index(['Host Id', 'Host Since', 'Name', 'Neighbourhood ', 'Property Type',
#        'Review Scores Rating (bin)', 'Room Type', 'Zipcode', 'Beds',
#        'Number of Records', 'Number Of Reviews', 'Price',
#        'Review Scores Rating'],
#       dtype='object')

# %%
# inspect df
df.head(5)
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
# look at price column
var = 'Price'
print(df[var].unique(),'\n') # list of unique values
print(df[var].value_counts(), '\n') # number of times each unique value occurs
print(df[var].hist()) # see value counts as bar graph
# Out:
# ['145' '37' '28' '199' '549' '149' '250' '90' '270' '290' '170' '59' '49'
#  '68' '285' '75' '100' '150' '700' '125' '175' '40' '89' '95' '99' '499'
#  '120' '79' '110' '180' '143' '230' '350' '135' '85' '60' '70' '55' '44'
#  '200' '165' '115' '74' '84' '129' '50' '185' '80' '190' '140' '45' '65'
#  '225' '600' '109' '1,990' '73' '240' '72' '105' '155' '160' '42' '132'
#  '117' '295' '280' '159' '107' '69' '239' '220' '399' '130' '375' '585'
#  '275' '139' '260' '35' '133' '300' '289' '179' '98' '195' '29' '27' '39'
#  '249' '192' '142' '169' '1,000' '131' '138' '113' '122' '329' '101' '475'
#  '238' '272' '308' '126' '235' '315' '248' '128' '56' '207' '450' '215'
#  '210' '385' '445' '136' '247' '118' '77' '76' '92' '198' '205' '299'
#  '222' '245' '104' '153' '349' '114' '320' '292' '226' '420' '500' '325'
#  '307' '78' '265' '108' '123' '189' '32' '58' '86' '219' '800' '335' '63'
#  '229' '425' '67' '87' '1,200' '158' '650' '234' '310' '695' '400' '166'
# ...

# %%
# remove commas
var = 'Price'
df[var] = df[var].str.replace(',', '', regex=True)

# %%
print(df[var].unique(),'\n') # list of unique values
# Out:
# ['145' '37' '28' '199' '549' '149' '250' '90' '270' '290' '170' '59' '49'
#  '68' '285' '75' '100' '150' '700' '125' '175' '40' '89' '95' '99' '499'
#  '120' '79' '110' '180' '143' '230' '350' '135' '85' '60' '70' '55' '44'
#  '200' '165' '115' '74' '84' '129' '50' '185' '80' '190' '140' '45' '65'
#  '225' '600' '109' '1990' '73' '240' '72' '105' '155' '160' '42' '132'
#  '117' '295' '280' '159' '107' '69' '239' '220' '399' '130' '375' '585'
#  '275' '139' '260' '35' '133' '300' '289' '179' '98' '195' '29' '27' '39'
#  '249' '192' '142' '169' '1000' '131' '138' '113' '122' '329' '101' '475'
#  '238' '272' '308' '126' '235' '315' '248' '128' '56' '207' '450' '215'
#  '210' '385' '445' '136' '247' '118' '77' '76' '92' '198' '205' '299'
#  '222' '245' '104' '153' '349' '114' '320' '292' '226' '420' '500' '325'
#  '307' '78' '265' '108' '123' '189' '32' '58' '86' '219' '800' '335' '63'
#  '229' '425' '67' '87' '1200' '158' '650' '234' '310' '695' '400' '166'
# ...

# %%
# coerce variable to numeric
var = 'Price'
df[var] = pd.to_numeric(df[var], errors='coerce')

print('After coercion: \n', df[var].describe(),'\n')
# Out:
# After coercion:
#  count    30478.000000
# mean       163.589737
# std        197.785454
# min         10.000000
# 25%         80.000000
# 50%        125.000000
# 75%        195.000000
# max      10000.000000
# Name: Price, dtype: float64

# %%
var = 'Price'
print(df[var].unique(),'\n') # list of unique values
print(df[var].value_counts(), '\n') # number of times each unique value occurs
print(df[var].hist(bins = 50)) # see value counts as bar graph
# Out:
# [  145    37    28   199   549   149   250    90   270   290   170    59
#     49    68   285    75   100   150   700   125   175    40    89    95
#     99   499   120    79   110   180   143   230   350   135    85    60
#     70    55    44   200   165   115    74    84   129    50   185    80
#    190   140    45    65   225   600   109  1990    73   240    72   105
#    155   160    42   132   117   295   280   159   107    69   239   220
#    399   130   375   585   275   139   260    35   133   300   289   179
#     98   195    29    27    39   249   192   142   169  1000   131   138
#    113   122   329   101   475   238   272   308   126   235   315   248
#    128    56   207   450   215   210   385   445   136   247   118    77
#     76    92   198   205   299   222   245   104   153   349   114   320
#    292   226   420   500   325   307    78   265   108   123   189    32
#     58    86   219   800   335    63   229   425    67    87  1200   158
# ...

# %% [markdown]
# To clean the Price variable, I firstly removed the commas from any of the values that were over 3 digits. Then because the values were strings, which doesn't make much sense for the price variable, I coerced them to be numeric values. When I inspected the data a bit and looked at unique values for the Price variable, I did not see any missing values.

# %% [markdown]
# Q 1.2

# %%
# read in police csv file
df = pd.read_csv('https://raw.githubusercontent.com/kpunsalan8/DS-3001-wrangling/refs/heads/main/assignment/data/mn_police_use_of_force.csv',low_memory=False)

# %%
# look at df
print(df.shape, '\n')
print(df.dtypes, '\n')
print(df.columns, '\n')
# Out:
# (12925, 13)
#
# response_datetime     object
# problem               object
# is_911_call           object
# primary_offense       object
# subject_injury        object
# force_type            object
# force_type_action     object
# race                  object
# sex                   object
# age                  float64
# type_resistance       object
# precinct               int64
# neighborhood          object
# dtype: object
#
# Index(['response_datetime', 'problem', 'is_911_call', 'primary_offense',
#        'subject_injury', 'force_type', 'force_type_action', 'race', 'sex',
#        'age', 'type_resistance', 'precinct', 'neighborhood'],
#       dtype='object')

# %%
var = 'subject_injury'
print(df[var].unique(),'\n')
print(df[var].value_counts(), '\n')
print(df[var].hist(), '\n')
# Out:
# [nan 'No' 'Yes']
#
# subject_injury
# Yes    1631
# No     1446
# Name: count, dtype: int64
#
# Axes(0.125,0.11;0.775x0.77)

# %%
df.head()
# Out:
#      response_datetime               problem is_911_call primary_offense  \
# 0  2016/01/01 00:47:36  Assault in Progress          Yes          DASLT1
# 1  2016/01/01 02:19:34                Fight           No          DISCON
# 2  2016/01/01 02:19:34                Fight           No          DISCON
# 3  2016/01/01 02:28:48                Fight           No          PRIORI
# 4  2016/01/01 02:28:48                Fight           No          PRIORI
#
#   subject_injury         force_type   force_type_action   race     sex   age  \
# 0            NaN       Bodily Force  Body Weight to Pin  Black    Male  20.0
# 1            NaN  Chemical Irritant       Personal Mace  Black  Female  27.0
# 2            NaN  Chemical Irritant       Personal Mace  White  Female  23.0
# 3            NaN  Chemical Irritant  Crowd Control Mace  Black    Male  20.0
# 4            NaN  Chemical Irritant  Crowd Control Mace  Black    Male  20.0
#
#          type_resistance  precinct   neighborhood
# ...

# %% [markdown]
# What proportion of values are missing? Is this concerning?

# %%
var = 'subject_injury'
missing_prop = df[var].isna().mean() # convert missing values to true (1), false (0) otherwise, and get proportion of missing values
print(f"Proportion of missing values: {missing_prop:.2%}") # print this proportion as percentage with 2 decimal places
# Out:
# Proportion of missing values: 76.19%

# %% [markdown]
# This is very concerning that well over half of the entries in this data frame having missing values for whether the subject was injured or not. It leads to thoughts about whether the police maybe didn't want to disclose whether the subject suffered an injury and the severity of injuries where this information is 'Missing'.

# %%
# clean subject_injury variable, handle NA's
# replace each missing value with a new category to indicate missing instead of just NaN
var = 'subject_injury'
df[var] = df[var].fillna('Missing')

# %%
print(df[var].unique(),'\n')
# Out:
# ['Missing' 'No' 'Yes']

# %%
print(df[var].value_counts(), '\n')
# Out:
# subject_injury
# Missing    9848
# Yes        1631
# No         1446
# Name: count, dtype: int64

# %% [markdown]
# Are there any patterns regarding where data is missing when cross-tabulated with force_type variable?

# %%
pd.crosstab(df['subject_injury'], df['force_type'])
# Out:
# force_type      Baton  Bodily Force  Chemical Irritant  Firearm  \
# subject_injury
# Missing             2          7051               1421        0
# No                  0          1093                131        2
# Yes                 2          1286                 41        0
#
# force_type      Gun Point Display  Improvised Weapon  Less Lethal  \
# subject_injury
# Missing                        27                 74           87
# No                             33                 34            0
# Yes                            44                 40            0
#
# force_type      Less Lethal Projectile  Maximal Restraint Technique  \
# subject_injury
# Missing                              0                          170
# No                                   1                            0
# Yes                                  2                            0
#
# force_type      Police K9 Bite  Taser
# subject_injury
# Missing                     31    985
# ...

# %% [markdown]
# I think that there are a few categories of force type used where the proportion of Missing injury answers are an extremely high proportion to clear answers. The categories of Bodily Force, Chemical Irritant, Less Lethal (?), Maximal Restraint Technique, and Taser stand out to me, and a few of these actually only have Missing values which is concerning.

# %% [markdown]
# Q 1.3

# %%
# load pretrial data from lecture
url = 'http://www.vcsc.virginia.gov/pretrialdataproject/October%202017%20Cohort_Virginia%20Pretrial%20Data%20Project_Deidentified%20FINAL%20Update_10272021.csv'
df = pd.read_csv(url,low_memory=False) # Pandas downloads and loads the .csv file for you

# %%
df.head()
# Out:
#   InternalStudyID REQ_REC# Defendant_Sex Defendant_Race Defendant_BirthYear  \
# 0        ADI00001        1             M              W                1986
# 1        ADI00007        3             M              B                1956
# 2        ADI00008        4             M              W                1990
# 3        CDI00036        6             M              B                1989
# 4        CDI00038        7             F              W                1988
#
#   Defendant_Age  Defendant_AgeGroup Defendant_AgeatCurrentArrest  \
# 0            31                   3                           31
# 1            60                   6                           60
# 2            27                   3                           27
# 3            27                   3                           27
# 4            28                   3                           28
#
#    Defendant_AttorneyTypeAtCaseClosure  Defendant_IndigencyStatus  ...  \
# ...

# %%
# look at unique values of variable
var = 'WhetherDefendantWasReleasedPretrial'
print(df[var].unique(),'\n')
print(df[var].value_counts())
# Out:
# [9 0 1]
#
# WhetherDefendantWasReleasedPretrial
# 1    19154
# 0     3801
# 9       31
# Name: count, dtype: int64

# %% [markdown]
# * not released = 0
# * released = 1
# * unclear = 9
#
# So 9's are basically missing values

# %%
# clean the WhetherDefendantWasReleasedPretrial variable as well as you can, replace missing values with np.nan
var = 'WhetherDefendantWasReleasedPretrial'
df[var] = df[var].replace(9, np.nan)

# %%
print(df[var].unique(),'\n')
print(df[var].value_counts())
# Out:
# [nan  0.  1.]
#
# WhetherDefendantWasReleasedPretrial
# 1.0    19154
# 0.0     3801
# Name: count, dtype: int64

# %% [markdown]
# Q 1.4

# %%
# look at ImposedSentenceAllChargeInContactEvent
var = 'ImposedSentenceAllChargeInContactEvent'
print(df[var].unique(),'\n')
print(df[var].value_counts())
# Out:
# [' ' '60' '12' '.985626283367556' '36' '6' '24' '5.91375770020534' '120'
#  '72' '11.9917864476386' '0' '2.95687885010267' '84' '108' '300' '240'
#  '180' '4' '96' '2' '54' '.328542094455852' '44' '5' '115' '132' '48'
#  '258' '34' '76' '.164271047227926' '.131416837782341' '111' '9' '3'
#  '1.97125256673511' '36.9856262833676' '.0657084188911704'
#  '35.4928131416838' '106.492813141684' '8' '35' '18.3141683778234' '480'
#  '32' '93' '234' '732' '1.16427104722793' '4.6570841889117' '21' '7'
#  '4.49281314168378' '18' '600' '43.1642710472279' '179' '52' '30' '20'
#  '192' '702' '14' '55' '53' '11.9055441478439' '114' '35.0061601642711'
#  '68' '.657084188911704' '46.6242299794661' '102' '65' '200' '57'
#  '24.3285420944559' '12.1642710472279' '117' '81.4928131416838'
#  '22.4928131416838' '1980' '3.6570841889117' '56' '10' '2.79260780287474'
#  '1' '47' '22' '1500' '40' '284' '11' '118' '42' '162' '156'
#  '47.2956878850103' '105' '51' '246' '29' '75' '324' '360'
# ...

# %%
# hint: look at SentenceTypeAllChargesAtConvictionInContactEvent
var = 'SentenceTypeAllChargesAtConvictionInContactEvent'
print(df[var].unique(),'\n')
print(df[var].value_counts())
# Out:
# [9 0 1 4 2]
#
# SentenceTypeAllChargesAtConvictionInContactEvent
# 4    8779
# 0    8720
# 1    4299
# 2     914
# 9     274
# Name: count, dtype: int64

# %%
# clean ImposedSentenceAllChargeInContactEvent
var = 'ImposedSentenceAllChargeInContactEvent'

# change empty string to NaN
df[var] = df[var].replace(' ', np.nan)

# %%
print(df[var].unique(),'\n')
# Out:
# [nan '60' '12' '.985626283367556' '36' '6' '24' '5.91375770020534' '120'
#  '72' '11.9917864476386' '0' '2.95687885010267' '84' '108' '300' '240'
#  '180' '4' '96' '2' '54' '.328542094455852' '44' '5' '115' '132' '48'
#  '258' '34' '76' '.164271047227926' '.131416837782341' '111' '9' '3'
#  '1.97125256673511' '36.9856262833676' '.0657084188911704'
#  '35.4928131416838' '106.492813141684' '8' '35' '18.3141683778234' '480'
#  '32' '93' '234' '732' '1.16427104722793' '4.6570841889117' '21' '7'
#  '4.49281314168378' '18' '600' '43.1642710472279' '179' '52' '30' '20'
#  '192' '702' '14' '55' '53' '11.9055441478439' '114' '35.0061601642711'
#  '68' '.657084188911704' '46.6242299794661' '102' '65' '200' '57'
#  '24.3285420944559' '12.1642710472279' '117' '81.4928131416838'
#  '22.4928131416838' '1980' '3.6570841889117' '56' '10' '2.79260780287474'
#  '1' '47' '22' '1500' '40' '284' '11' '118' '42' '162' '156'
#  '47.2956878850103' '105' '51' '246' '29' '75' '324' '360'
# ...

# %%
# want to convert values to numeric
var = 'ImposedSentenceAllChargeInContactEvent'
df[var] = pd.to_numeric(df[var], errors='coerce')

print('After coercion: \n', df[var].describe(),'\n')
# Out:
# After coercion:
#  count   13933
# mean       20
# std        64
# min         0
# 25%         0
# 50%         2
# 75%        12
# max      2208
# Name: ImposedSentenceAllChargeInContactEvent, dtype: float64

# %% [markdown]
# To clean the ImposedSentenceAllChargeInContactEvent variable, I first noticed a missing value and replaced it with NaN. Then I coerced the values to be numeric values. The values are expressed in months, with the decimal fractions expressing fractions of months, or a certain number of days. When looking at the other related variable, SentenceTypeAllChargesAtConvictionInContactEvent, it seems like the main 3 differentiations recognized are 0 for no probation, 1 for jail up to 12 months, and 2 for prison for one year or more. So, my interpretation of this hint is that these decimal values can be cleaned further by simplifying the numbers and simply showing whether the imposed sentence is less or more than 12 months as it seems that that is that most important distinction not the specificities of each unique value.

# %%
df.loc[df['ImposedSentenceAllChargeInContactEvent'].isna(), 'ImposedSentenceAllChargeInContactEvent'] = 9 # value missing

df.loc[ df['ImposedSentenceAllChargeInContactEvent'] == 0, 'ImposedSentenceAllChargeInContactEvent'] = 0 # no sentence
df.loc[ (df['ImposedSentenceAllChargeInContactEvent'] < 12) & (df['ImposedSentenceAllChargeInContactEvent'] != 0), 'ImposedSentenceAllChargeInContactEvent'] = 1 # less than a year
df.loc[ df['ImposedSentenceAllChargeInContactEvent'] >= 12, 'ImposedSentenceAllChargeInContactEvent'] = 2 # 1 year or more

# %%
var = 'ImposedSentenceAllChargeInContactEvent'

print(df[var].value_counts())
# Out:
# ImposedSentenceAllChargeInContactEvent
# 1    13403
# 0     4953
# 2     4630
# Name: count, dtype: int64

# %% [markdown]
# **Q2.** Go to https://sharkattackfile.net/ and download their dataset on shark attacks.
#
# 1. Open the shark attack file using Pandas. It is probably not a csv file, so `read_csv` won't work.
# 2. Drop any columns that do not contain data.
# 3. Clean the year variable. Describe the range of values you see. Filter the rows to focus on attacks since 1940. Are attacks increasing, decreasing, or remaining constant over time?
# 4. Clean the Age variable and make a histogram of the ages of the victims.
# 5. What proportion of victims are male?
# 6. Clean the `Type` variable so it only takes three values: Provoked and Unprovoked and Unknown. What proportion of attacks are unprovoked?
# 7. Clean the `Fatal Y/N` variable so it only takes three values: Y, N, and Unknown.
# 8. Are sharks more likely to launch unprovoked attacks on men or women? Is the attack more or less likely to be fatal when the attack is provoked or unprovoked? Is it more or less likely to be fatal when the victim is male or female? How do you feel about sharks?
# 9. What proportion of attacks appear to be by white sharks? (Hint: `str.split()` makes a vector of text values into a list of lists, split by spaces.)

# %%
# Q 2.1

# Define file path
file_path = "/content/GSAF5.xls"

# Read the Excel file
df = pd.read_excel(file_path)

print(df.head())
# Out:
#                   Date    Year        Type        Country              State  \
# 0  2025-01-23 00:00:00  2025.0  Unprovoked      Australia  Western Australia
# 1  2025-01-22 00:00:00  2025.0  Unprovoked      Australia  Western Australia
# 2  2025-01-11 00:00:00  2025.0    Provoked            USA             Hawaii
# 3  2025-01-02 00:00:00  2025.0  Unprovoked  New Caledonia       Grande Terre
# 4  2025-01-02 00:00:00  2025.0  Unprovoked      Australia    South Australia
#
#                                   Location      Activity  \
# 0                           Shipwreck Cove       Bathing
# 1                           Cheynes beach        Surfing
# 2            Off Haleiwa Boat Harbour Oahu        Diving
# 3              Islet of Kendek near Koumac  Spearfishing
# 4  Granites Beach near Westall Streaky Bay       Surfing
#
#                                      Name Sex Age  ...  \
# 0                                    Boy    M  12  ...
# ...

# %%
print(df.isna().sum())  # Show count of NaN values per column
print(df.info())  # Show column types and non-null counts
# Out:
# Date                 0
# Year                 2
# Type                18
# Country             50
# State              482
# Location           565
# Activity           585
# Name               219
# Sex                579
# Age               2994
# Injury              35
# Fatal Y/N          561
# Time              3526
# Species           3132
# Source              19
# pdf                193
# href formula       198
# href               196
# Case Number        194
# Case Number.1      195
# original order     193
# Unnamed: 21       6991
# Unnamed: 22       6990
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6992 entries, 0 to 6991
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6992 non-null   object
#  1   Year            6990 non-null   float64
#  2   Type            6974 non-null   object
#  3   Country         6942 non-null   object
# ...

# %%
# 2.2 drop columns where virtually all values are empty
# Drop columns containing "Unnamed" in their names
df = df.loc[:, ~df.columns.str.contains('Unnamed')]

# %%
print(df.head())
# Out:
#                   Date    Year        Type        Country              State  \
# 0  2025-01-23 00:00:00  2025.0  Unprovoked      Australia  Western Australia
# 1  2025-01-22 00:00:00  2025.0  Unprovoked      Australia  Western Australia
# 2  2025-01-11 00:00:00  2025.0    Provoked            USA             Hawaii
# 3  2025-01-02 00:00:00  2025.0  Unprovoked  New Caledonia       Grande Terre
# 4  2025-01-02 00:00:00  2025.0  Unprovoked      Australia    South Australia
#
#                                   Location      Activity  \
# 0                           Shipwreck Cove       Bathing
# 1                           Cheynes beach        Surfing
# 2            Off Haleiwa Boat Harbour Oahu        Diving
# 3              Islet of Kendek near Koumac  Spearfishing
# 4  Granites Beach near Westall Streaky Bay       Surfing
#
#                                      Name Sex Age  ... Fatal Y/N     Time  \
# 0                                    Boy    M  12  ...         N  1711hrs
# ...

# %%
# 2.3 Year variable
# change to numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# %%
# describe range of values
print(df['Year'].describe())
# Out:
# count    6990.000000
# mean     1935.018598
# std       272.082794
# min         0.000000
# 25%      1947.000000
# 50%      1986.000000
# 75%      2009.000000
# max      2026.000000
# Name: Year, dtype: float64

# %%
print(df['Year'].unique(),'\n')
# Out:
# [2025. 2024. 2026. 2023. 2022. 2021. 2020. 2019. 2018. 2017.   nan 2016.
#  2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007. 2006. 2005. 2004.
#  2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996. 1995. 1984. 1994. 1993.
#  1992. 1991. 1990. 1989. 1969. 1988. 1987. 1986. 1985. 1983. 1982. 1981.
#  1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973. 1972. 1971. 1970. 1968.
#  1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960. 1959. 1958. 1957. 1956.
#  1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948. 1848. 1947. 1946. 1945.
#  1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937. 1936. 1935. 1934. 1933.
#  1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925. 1924. 1923. 1922. 1921.
#  1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913. 1912. 1911. 1910. 1909.
#  1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901. 1900. 1899. 1898. 1897.
#  1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889. 1888. 1887. 1886. 1885.
#  1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877. 1876. 1875. 1874. 1873.
# ...

# %%
# drop rows that are na or 0
df = df[df['Year'].notna() & (df['Year'] != 0)]

# %%
# filter rows to attacks since 1940
df = df[df['Year'] >= 1940]

# %%
# what is the trend of attacks: increasing, decreasing, or constant
# Check trends over time
df['Year'].value_counts().sort_index().plot(kind='line', title='Attacks Over Time')

# add labels
plt.xlabel('Year')
plt.ylabel('Number of Attacks')

plt.show()

# %% [markdown]
# The number of shark attacks has been increasing since 1940.

# %%
# 2.4 clean Age variable
# change to numeric
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
# drop rows with na in age
df.dropna(subset=['Age'], inplace=True)

# %%
# create histogram of ages of victims
plt.hist(df['Age'], bins=10)

# add labels
plt.xlabel('Age')
plt.ylabel('Frequency')

# add title
plt.title('Ages of Victims')

plt.show()

# %%
print(df['Sex'].value_counts())
# Out:
# Sex
# M        4295
# F         706
# M           2
#  M          1
# lli         1
# M x 2       1
# Name: count, dtype: int64

# %%
# clean Sex variable
df["Sex"] = df["Sex"].replace({
    "M": "M",
    " M": "M",
    "M x 2": "M"
  })

df["Sex"] = df["Sex"].where(df["Sex"].isin(["M", "F"]))

# %%
# 2.5 what proportion of victims are male?
proportion_m = (df['Sex'].str.upper() == 'M').mean()
print(f"Proportion of male victims: {proportion_m:.2%}")
# Out:
# Proportion of male victims: 78.73%

# %%
print(df['Type'].value_counts())
# Out:
# Type
# Unprovoked             4055
# Provoked                516
# Invalid                 402
# Watercraft              280
# Sea Disaster            156
# Questionable             22
# Boat                      7
#  Provoked                 2
# ?                         1
# Unconfirmed               1
# Unverified                1
# Under investigation       1
# Name: count, dtype: int64

# %%
# 2.6 clean Type variable to only 3 values - Provoked, Unprovoked, Unknown
df["Type"] = df["Type"].replace({
    "Invalid": "Unknown",
    "Watercraft": "Unknown",
    "Sea Disaster": "Unknown",
    "Questionable": "Unknown",
    "Boat": "Unknown",
    "?": "Unknown",
    "Unconfirmed": "Unknown",
    "Unverified": "Unknown",
    "Under Investigation": "Unknown"
})
df["Type"] = df["Type"].where(df["Type"].isin(["Provoked", "Unprovoked"]), "Unknown")

# %%
print(df["Type"].value_counts())
# Out:
# Type
# Unprovoked    4055
# Unknown        887
# Provoked       516
# Name: count, dtype: int64

# %%
# what proportion is Unprovoked?
prop_unprovoked = (df["Type"] == "Unprovoked").mean()
print(f"Proportion of unprovoked attacks: {prop_unprovoked:.2%}")
# Out:
# Proportion of unprovoked attacks: 74.29%

# %%
print(df["Fatal Y/N"].value_counts())
# Out:
# Fatal Y/N
# N          4178
# Y           811
# UNKNOWN      45
#  N            7
# F             4
# M             3
# n             1
# Nq            1
# 2017          1
# Y x 2         1
# Name: count, dtype: int64

# %%
# 2.7 clean Fatal Y/N variable to 3 values - Y, N, and Unknown
df["Fatal Y/N"] = df["Fatal Y/N"].replace({
    "UNKNOWN": "Unknown",
    " N": "N",
    "F": "Y",
    "M": "Unknown",
    "n": "N",
    "Nq": "Unknown",
    "2017": "Unknown",
    "Y x 2": "Y"
  })

df["Fatal Y/N"] = df["Fatal Y/N"].where(df["Fatal Y/N"].isin(["Y", "N"]), "Unknown")

# %%
print(df["Fatal Y/N"].value_counts())
# Out:
# Fatal Y/N
# N          4186
# Y           816
# Unknown     456
# Name: count, dtype: int64

# %%
# 2.8
# More likely to launch unprovoked attacks on men or women?
pd.crosstab(df['Sex'], df['Type'])
# Out:
# Type  Provoked  Unknown  Unprovoked
# Sex
# F           28       78         600
# M          444      542        3311

# %% [markdown]
# They are more likely to launch unprovoked attacks on men.

# %%
# Is attack more or less likely to be fatal when the attack is provoked or unprovoked?
pd.crosstab(df['Fatal Y/N'], df['Type'])
# Out:
# Type       Provoked  Unknown  Unprovoked
# Fatal Y/N
# N               495      367        3324
# Unknown           9      397          50
# Y                12      123         681

# %% [markdown]
# The attack is more likely to be fatal when it is unprovoked.

# %%
# Is it more or less likely to be fatal when the victim is male or female?
pd.crosstab(df['Fatal Y/N'], df['Sex'])
# Out:
# Sex          F     M
# Fatal Y/N
# N          560  3326
# Unknown     59   318
# Y           87   653

# %% [markdown]
# It is more likely to be fata when the victim is a man.

# %% [markdown]
# How do you feel about sharks?
#
# They make me a bit nervous, but I wouldn't say they are one of my biggest fears. I definitely would not do anything to provoke a shark!

# %%
print(df.columns)
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order'],
#       dtype='object')

# %%
# 2.9 proportion of attacks by white sharks

# see what column contains
var = 'Species '
print(df[var].unique(),'\n')
print(df[var].value_counts())
# Out:
# ['Not stated' 'Bronze whaler' 'Reportedly Tiger or Bull shark' ...
#  'White shark, species identity confirmed by tooth pattern'
#  'White shark, 160-kg [353-lb], identity confirmed by tooth pattern'
#  ' White shark']
#
# Species
# White shark                                           180
# Shark involvement prior to death was not confirmed     98
# Shark involvement not confirmed                        86
# Invalid                                                78
# Tiger shark                                            75
#                                                      ...
# White shark, 16'                                        1
# White shark, 5m                                         1
# Raggedtooth shark, 150-kg                               1
# White shark, 12' to 15'                                 1
#  White shark                                            1
# Name: count, Length: 1549, dtype: int64

# %%
# check if "white shark" appears anywhere in the Species column, make it so case doesn't matter
white_shark_count = df["Species "].str.contains("white shark", case=False, na=False).sum()

# Total number of non-null entries in the Species column
total_sharks = df["Species "].notna().sum()

# Calculate proportion
white_shark_proportion = white_shark_count / total_sharks

print(f"Proportion of attacks by white sharks: {white_shark_proportion:.2%}")
# Out:
# Proportion of attacks by white sharks: 19.40%

# %% [markdown]
# **Q3.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#   5. How is "Tidy Data" defined in section 2.3?
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?

# %% [markdown]
# 3.1
# It's about component of data cleaning called data tidying, and how we can make data cleaning easier and more effective. Tidy datasets have a specific, consistent structure that provide an advantage for gaining insights from analysis and modeling.
#
# 3.2
# The "tidy data standard" is the standard of structuring the dataset in a specific way that makes it easier and more efficient to analyse the data.
#
# 3.3
# Every messy dataset is messy in its own way, meaning that data sets that are not tidy, are all organized in very different unique ways, which makes it difficult to analyze them in a standardized way each time you deal with data.
#
# The second sentence means that, for a given dataset, it may be unclear or a bit confusing how the author of the dataset chose to organize observations and variables. Some variables may seem like they should be categories of one variable, and some observations may not make sense all in one column.
#
# 3.4
# * Values - usually either numbers or strings
# * Variables - a variable contains all values that measure the same underlying attribute across units (ex. temp, height)
# * Observations - contains all values measured on the same unit across attributes (ex. person, day)
#
# 3.5
# Tidy data = a standard way of mapping the meaning of a dataset to its structure
# * each variable forms a column
# * each observation forms a row
# * each type of observational unit forms a table
#
# 3.6
#
# 5 most common problems
# 1. column headers are values not variable names
# 2. multiple values are stored in one column
# 3. variables are stored in both rows and columns
# 4. multiple types of observational units are stored in the same table
# 5. a single observational unit is stored in multiple tables
#
# The data in Table 4 are messy because the column headers are a value (the income) which could be better expressed as its own column, and then the frequency could be it's own column.
# Melting a dataset is to stack it by turning columns which are already variables into rows.
#
# 3.7
# Table 11 is messy because there are columns that should really be consolidated all into 1 column. There is a column for each possible day of the month when that could be melted into a column containing each observation for each day.
#
# Table 12 is tidier than Table 11 because those day variables have been molten into their own column.
#
# 3.8
# The chicken-and-egg problem is that if tidy data is only as useful as tools that work with it, then those tools will be linked to working with tidy data. She hopes that this tidy data framework is not the final solution, and that in the future others will continue to develop even better solutions and strategies. She also mentions that in the future she wants to use methodologies from other fields such as user-centered design and human-computer interaction to further improvement in designing data analysis tools.

# %% [markdown]
# **Q4.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?
